# %% [markdown]
# # Lendo os PDFs

# %%
from pypdf import PdfReader
from langchain_text_splitters import RecursiveCharacterTextSplitter
import json
import re
import faiss
import numpy as np
import pandas as pd

def load_pdf(path):
    reader = PdfReader(path)
    pages = []
    for i, page in enumerate(reader.pages):
        text = page.extract_text() or ""
        pages.append({"page_number": i+1, "text": text})
    return pages

# %%
import spacy

try:
    nlp = spacy.load("pt_core_news_lg")
except OSError:
    raise RuntimeError("Modelo 'pt_core_news_lg' não encontrado. Instale com: python -m spacy download pt_core_news_lg")


def extract_entities_pt(text):
    doc_q = nlp(text)
    ents = [(ent.text, ent.label_) for ent in doc_q.ents]
    # Remove duplicatas mantendo ordem
    seen = set()
    unique_ents = []
    for t, l in ents:
        key = (t.lower(), l)
        if key not in seen:
            seen.add(key)
            unique_ents.append({"text": t, "label": l})
    return unique_ents

def expand_query_with_entities(query: str, entities: list):
    if not entities:
        return query
    # Cria um reforço leve adicionando entidades no final
    ents_text = " ".join([e["text"] for e in entities])
    expanded = f"{query} {ents_text}".strip()
    return expanded

# %%
def tratar_texto(text):
    if not text:
        return ""
    text = re.sub(r'\r\n|\r', '\n', text)
    text = re.sub(r'\n{2,}', '\n\n', text)
    text = re.sub(r'[ \t]{2,}', ' ', text)
    text = text.strip()
    return text

# %%
pdfs = [
    {
        "file": "C:\\Users\\Guilherme Monteiro\\Desktop\\codigos_gerais\\proj4\\textos\\Apologia-de-Socrates-de-Platao.pdf",
        "titulo": "Apologia de Sócrates",
        "autor": "Platão",
        "prefix": "apologia"
    },
    {
        "file": "C:\\Users\\Guilherme Monteiro\\Desktop\\codigos_gerais\\proj4\\textos\\Carta-a-Meneceu-Sobre-a-Felicidade-por-Epicuro.pdf",
        "titulo": "Carta a Meneceu",
        "autor": "Epicuro",
        "prefix": "meneceu"
    },
    {
        "file": "C:\\Users\\Guilherme Monteiro\\Desktop\\codigos_gerais\\proj4\\textos\\O-Mito-da-Caverna-trecho-do-A-Republica-de-Platao.pdf",
        "titulo": "O Mito da Caverna",
        "autor": "Platão",
        "prefix": "caverna"
    }
]

# %%
all_documents = []

for item in pdfs:
    pages = load_pdf(item["file"])
    for p in pages:
        all_documents.append({
            "titulo": item["titulo"],
            "autor": item["autor"],
            "prefix": item["prefix"],
            "pagina_pdf": p["page_number"],
            "texto_bruto": tratar_texto(p["text"])
        })
# Out:
# Ignoring wrong pointing object 5 0 (offset 0)

# %%
len(all_documents), all_documents[-1]
# Out:
# (37,
#  {'titulo': 'O Mito da Caverna',
#   'autor': 'Platão',
#   'prefix': 'caverna',
#   'pagina_pdf': 5,
#   'texto_bruto': 'caso eis o que me aparece tal como me aparece; nos últimos limites \ndo mundo inteligível aparece-me a idéia do Bem, que se percebe com \ndificuldade, mas que não se pode ver sem concluir que ela é a causa \nde tudo o que há de reto e de belo. No mundo visível, ela gera a luz e \no senhor da luz, no mundo inteligível ela própria é a soberana que \ndispensa a verdade e a inteligência. Acrescento que é preciso vê-la se \nquer comportar-se com sabedoria, seja na vida privada, seja na vida \npública.\nGlauco: Tanto quanto sou capaz de compreender-te, concordo \ncontigo.\nReferência:\nA Alegoria da caverna: A Republica, 514a-517c tradução de Lucy \nMagalhães. \nIn: MARCONDES, Danilo. Textos Básicos de Filosofia: dos Pré-\nsocráticos a Wittgenstein. 2a ed. Rio de Janeiro: Jorge Zahar Editor, \n2000.'})

# %% [markdown]
# ## Criando os chunks

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size=800,
    chunk_overlap=100,
    separators=["\n\n", "\n", ". ", "? ", "! ", " "]
)

chunks_final = []

for doc in all_documents:
    splits = splitter.split_text(doc["texto_bruto"])
    
    for idx, chunk in enumerate(splits):
        chunk_id = f"{doc['prefix']}_{doc['pagina_pdf']}_{idx}"
        
        # Extrai entidades nomeadas (NER) com spaCy
        doc_spacy = nlp(chunk)
        ner = [{"text": ent.text, "label": ent.label_} for ent in doc_spacy.ents]
        
        chunks_final.append({
            "titulo": doc["titulo"],
            "autor": doc["autor"],
            "capitulo": None,
            "pagina_pdf": doc["pagina_pdf"],
            "chunk_id": chunk_id,
            "texto": chunk,
            "ner": ner
        })

len(chunks_final)
# Out:
# 130

# %%
chunks_final[-1]
# Out:
# {'titulo': 'O Mito da Caverna',
#  'autor': 'Platão',
#  'capitulo': None,
#  'pagina_pdf': 5,
#  'chunk_id': 'caverna_5_0',
#  'texto': 'caso eis o que me aparece tal como me aparece; nos últimos limites \ndo mundo inteligível aparece-me a idéia do Bem, que se percebe com \ndificuldade, mas que não se pode ver sem concluir que ela é a causa \nde tudo o que há de reto e de belo. No mundo visível, ela gera a luz e \no senhor da luz, no mundo inteligível ela própria é a soberana que \ndispensa a verdade e a inteligência. Acrescento que é preciso vê-la se \nquer comportar-se com sabedoria, seja na vida privada, seja na vida \npública.\nGlauco: Tanto quanto sou capaz de compreender-te, concordo \ncontigo.\nReferência:\nA Alegoria da caverna: A Republica, 514a-517c tradução de Lucy \nMagalhães. \nIn: MARCONDES, Danilo. Textos Básicos de Filosofia: dos Pré-\nsocráticos a Wittgenstein. 2a ed. Rio de Janeiro: Jorge Zahar Editor, \n2000.',
#  'ner': [{'text': 'Bem', 'label': 'MISC'},
#   {'text': 'Glauco', 'label': 'PER'},
#   {'text': 'Referência', 'label': 'LOC'},
#   {'text': 'A Alegoria', 'label': 'MISC'},
#   {'text': 'Republica', 'label': 'MISC'},
#   {'text': 'Lucy \nMagalhães', 'label': 'PER'},
#   {'text': 'In: MARCONDES', 'label': 'MISC'},
#   {'text': 'Danilo', 'label': 'PER'},
#   {'text': 'Textos Básicos de Filosofia', 'label': 'MISC'},
#   {'text': 'Pré-', 'label': 'ORG'},
#   {'text': 'Wittgenstein', 'label': 'PER'},
#   {'text': 'Rio de Janeiro', 'label': 'LOC'},
#   {'text': 'Jorge Zahar Editor', 'label': 'PER'}]}

# %% [markdown]
# ## Salvando cópia em JSON

# %%
output_file = "chunks_filosofia.json"

with open(output_file, "w", encoding="utf-8") as f:
    json.dump(chunks_final, f, ensure_ascii=False, indent=2)

output_file
# Out:
# 'chunks_filosofia.json'

# %% [markdown]
# ### Criando os Embeddings
# Aqui, estou utilizando um modelo multi linguas do Alibaba, treinado para criação de embeddings semanticos

# %%
from transformers import AutoTokenizer, AutoModel
import torch
import numpy as np

# BERTimbau (Portuguese BERT)
tokenizer = AutoTokenizer.from_pretrained('neuralmind/bert-base-portuguese-cased')
bert_model = AutoModel.from_pretrained('neuralmind/bert-base-portuguese-cased')
bert_model.eval()


def encode_text_mean_pool(text: str):
    """Encode a single text using BERTimbau and return a mean-pooled embedding.
    Excludes [CLS]/[SEP] special tokens from the mean.
    """
    inputs = tokenizer(text, return_tensors='pt', truncation=True, max_length=512)
    with torch.no_grad():
        outputs = bert_model(**inputs)
        token_embeds = outputs.last_hidden_state.squeeze(0)  # [seq_len, hidden]
    # Identify special tokens and mask them
    ids = inputs['input_ids'].squeeze(0)
    # Exclude first ([CLS]) and last ([SEP]) positions when possible
    start = 1 if ids.numel() > 2 else 0
    end = -1 if ids.numel() > 2 else ids.numel()
    valid_tokens = token_embeds[start:end]
    if valid_tokens.numel() == 0:
        valid_tokens = token_embeds
    vec = valid_tokens.mean(dim=0)  # [hidden]
    return vec.cpu().numpy()


lista_emb = []
texts = []
metadados = []

for chunk in chunks_final:
    # concatena metadados ao texto para melhorar recuperação
    ner_text = " ".join([e.get("text", "") for e in chunk.get("ner", [])])
    texto_meta = (
        f"TITULO: {chunk['titulo']} AUTOR: {chunk['autor']} PAGINA: {chunk['pagina_pdf']} "
        f"NER: {ner_text} TEXTO: {chunk['texto']}"
    ).strip()

    emb = encode_text_mean_pool(texto_meta)
    texts.append(texto_meta)
    metadados.append({
        "titulo": chunk["titulo"],
        "autor": chunk["autor"],
        "pagina_pdf": chunk["pagina_pdf"],
        "chunk_id": chunk["chunk_id"],
        "ner": chunk.get("ner", [])
    })
    lista_emb.append(emb)

emb_matrix = np.vstack(lista_emb).astype("float32")
# Out:
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`

# %% [markdown]
# ### Armazenando meus vetores dentro do FAISS Index
# Aqui armazeno meus vetores em um banco FAISS

# %%
embeddings = emb_matrix
dim = embeddings.shape[1]
index = faiss.IndexFlatL2(dim)
index.add(embeddings)

# estrutura tabular mínima 
df_subset = pd.DataFrame({
    "TextoManifestacao": texts,
    "titulo": [m["titulo"] for m in metadados],
    "autor": [m["autor"] for m in metadados],
    "pagina_pdf": [m["pagina_pdf"] for m in metadados],
    "chunk_id": [m["chunk_id"] for m in metadados],
    "ner": [m["ner"] for m in metadados],
    "embeddings": list(embeddings)
})

# %% [markdown]
# ### Carregando meu LLM local
#
# Carregamento de um LLM local para realização do RAG

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()

client = OpenAI(
    base_url="https://router.huggingface.co/v1",
    api_key=os.getenv("TOKEN"),
)

def llm_generate(system_prompt: str, user_prompt: str, max_tokens: int = 256, temperature: float = 0.7):
    completion = client.chat.completions.create(
        model="deepseek-ai/DeepSeek-V3.1-Terminus:novita",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt},
        ],
        max_tokens=max_tokens,
        temperature=temperature,
        top_p=0.95,
    )
    return completion.choices[0].message.content

# %% [markdown]
# ## Criando a Pipeline do RAG

# %% [markdown]
# - Aqui esta sendo feito um rewriting da query para gerar um texto mais objetivo para busca por semelhnaça de cosseno.

# %%
# remoçao do bloco pois estava dando incoerencia 

def requery(query):
    return query

# %% [markdown]
# ### Realizando o reranking das top 10 textos, recuperando as 5 mais próximas

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch

RERANK_ENTITY_BOOST = 0.25  # incremento multiplicativo para docs com interseção de entidades

tokenizer_rerank = AutoTokenizer.from_pretrained("cross-encoder/mmarco-mMiniLMv2-L12-H384-v1")
model_rerank = AutoModelForSequenceClassification.from_pretrained("cross-encoder/mmarco-mMiniLMv2-L12-H384-v1")
model_rerank.eval()

def _has_entity_intersection(query_entities, doc_ner_list):
    if not query_entities or not doc_ner_list:
        return False
    qset = set(e["text"].lower() for e in query_entities if e.get("text"))
    dset = set(e.get("text", "").lower() for e in doc_ner_list if isinstance(e, dict))
    return len(qset.intersection(dset)) > 0

def reranking(query, retrived_docs, top_k=10, query_entities=None, verbose=False):
    ents_text = " " + " ".join([e["text"] for e in (query_entities or [])]) if query_entities else ""
    query_with_ents = (query + ents_text).strip()

    pares = [(query_with_ents, doc) for _, doc in retrived_docs]
    if verbose:
        print("\nRealizando o re-ranking (Cross-Encoder) usando entidades + boost por interseção...\n")

    tokens = tokenizer_rerank(pares, padding=True, truncation=True, return_tensors="pt", max_length=800)

    with torch.no_grad():
        results = model_rerank(**tokens).logits.squeeze(-1)

    docs = [doc for _, doc in retrived_docs]
    idx_doc = [idx for idx, _ in retrived_docs]

    # bost nos scores se houver interseção de entidades
    boosted_scores = []
    for score, di in zip(results.tolist(), idx_doc):
        try:
            doc_ner = df_subset.iloc[di]["ner"]
        except Exception:
            doc_ner = []
        if _has_entity_intersection(query_entities or [], doc_ner):
            score = score * (1.0 + RERANK_ENTITY_BOOST)
        boosted_scores.append(score)

    doc_results = list(zip(idx_doc, docs, boosted_scores))
    top_docs = sorted(doc_results, key=lambda x: x[2], reverse=True)

    if verbose:
        print("Documentos Recuperados (com reforço de entidades + boost):")
        for i, (_, doc, valor) in enumerate(top_docs[:top_k]):
            print(f"{i+1} - Score: {valor:.4f} | Manifestação: {doc[:100]}...")

    return top_docs[:top_k]

# %% [markdown]
# ### Realizando o Highligh dos trechos mais coerentes com as perguntas do usuario encontrados dentro dos top 5 textos

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from langchain_text_splitters import RecursiveCharacterTextSplitter

HIGHLIGHT_CHUNK_SIZE = 500
HIGHLIGHT_CHUNK_OVERLAP = 120
HIGHLIGHT_TOP_PER_DOC = 2
HIGHLIGHT_GLOBAL_MAX_CHARS = 4000
HIGHLIGHT_MIN_INDEX_GAP = 3  # distância mínima entre índices de chunks

# utiliza a função de BERTimbau definida anteriormente
def encode_batch_mean_pool(texts):
    if not texts:
        return np.zeros((0, 768), dtype=np.float32)
    vecs = [encode_text_mean_pool(t) for t in texts]
    return np.vstack(vecs).astype("float32")


def highlight(query_emb, docs, lista_idx, verbose=False):

    if verbose:
        print("\nRealizando o highlight dos documentos (conservador + diversidade)...\n")
    dicionario_chunks = {}

    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=HIGHLIGHT_CHUNK_SIZE,
        chunk_overlap=HIGHLIGHT_CHUNK_OVERLAP,
        separators=["\n\n", "\n", ". ", "? ", "! ", " "]
    )

    for idx, doc in zip(lista_idx, docs):
        chunks = text_splitter.split_text(doc)
        dicionario_chunks[idx] = chunks
        if verbose:
            print(f"Documento {idx}:")
            for j, chunk in enumerate(dicionario_chunks[idx][:2]):
                print(f"Chunk {j+1}: {chunk[:200]}...")
            print("\n")
    
    if verbose:
        print("\nSelecionando top chunks por similaridade (com diversidade)...\n")
    highlighted_chunks = []
    total_chars = 0

    for idx, chunks in dicionario_chunks.items():
        if not chunks:
            highlighted_chunks.append((idx, ""))
            continue
        embeddings_chunks = encode_batch_mean_pool(chunks)
        similarities = cosine_similarity(query_emb.reshape(1, -1), embeddings_chunks)
        sorted_indices = np.argsort(similarities[0])[::-1]

        selecionados = []
        selected_indices = []
        for i in sorted_indices:
            # respeita distância mínima entre índices
            if any(abs(i - si) < HIGHLIGHT_MIN_INDEX_GAP for si in selected_indices):
                continue
            c = chunks[i]
            if total_chars + len(c) <= HIGHLIGHT_GLOBAL_MAX_CHARS:
                selecionados.append(c)
                selected_indices.append(i)
            if len(selecionados) >= HIGHLIGHT_TOP_PER_DOC:
                break
        
        texto_final = "\n".join(selecionados)
        total_chars += sum(len(s) for s in selecionados)
        highlighted_chunks.append((idx, texto_final))
        if verbose:
            print(f"Documento {idx} selecionado com {len(selecionados)} chunks (indices={selected_indices}), total chars acumulados: {total_chars}")
            print("\n")
    
    return highlighted_chunks

# %% [markdown]
# ### Função que opera o RAG

# %%
def rag_response(query, index, df_subset, top_k=10, verbose=False):
    # reconhecimento de entidades na query
    query_ents = extract_entities_pt(query)

    # expansão simples com entidades (sem LLM)
    busca = expand_query_with_entities(query, query_ents)

    # embedding da consulta expandida via BERTimbau
    query_embedding = encode_text_mean_pool(busca).astype("float32")

    # recuperação por similaridade de cosseno (contexts iniciais)
    distances, indices = index.search(np.array([query_embedding]), top_k)

    controle_idx = []
    retrieved_docs = []
    for i, idx in enumerate(indices[0]):
        retrieved_docs.append(df_subset.iloc[idx]['TextoManifestacao'])
        controle_idx.append(idx)

    # highlighting
    docs_highlight = highlight(query_emb=query_embedding, docs=retrieved_docs, lista_idx=controle_idx, verbose=verbose)

    # reranking com Cross-Encoder usando entidades
    docs_rerank = reranking(query=busca, retrived_docs=docs_highlight, top_k=top_k, query_entities=query_ents, verbose=verbose)

    # contexto para o LLM (top documentos)
    context = "\n\n".join([doc for _, doc, _ in docs_rerank])

    system = (
        "Você é um grande assistente de IA expecialista em Sóciologia e Filosófia clássica que responde perguntas baseado no contexto fornecido."
        "Monte respostas coesas em completas utilizando o material fornecido como base, e não se esqueca de mencionar o trecho utilizado como referencia ao final da resposta, atrelando ele ao que foi respondido."
        "Se não houver informação suficiente, diga: 'Eu não tenho informações suficientes para responder esta pergunta.'"
    )
    user = f"Contexto:\n{context}\n\nPergunta:\n{query}"

    response = llm_generate(system_prompt=system, user_prompt=user, max_tokens=256, temperature=0.7)

    # preparar saídas estruturadas para avaliação
    initial_contexts = [
        {
            "idx": int(iidx),
            "preview": df_subset.iloc[iidx]['TextoManifestacao'][:300],
            "titulo": df_subset.iloc[iidx]['titulo'],
            "autor": df_subset.iloc[iidx]['autor'],
            "pagina_pdf": df_subset.iloc[iidx]['pagina_pdf'],
            "chunk_id": df_subset.iloc[iidx]['chunk_id'],
            "ner": df_subset.iloc[iidx]['ner'],
        }
        for iidx in controle_idx
    ]

    reranked = [
        {
            "idx": int(iidx),
            "score": float(score),
            "preview": doc[:300],
            "titulo": df_subset.iloc[iidx]['titulo'],
            "autor": df_subset.iloc[iidx]['autor'],
            "pagina_pdf": df_subset.iloc[iidx]['pagina_pdf'],
            "chunk_id": df_subset.iloc[iidx]['chunk_id'],
            "ner": df_subset.iloc[iidx]['ner'],
        }
        for (iidx, doc, score) in docs_rerank
    ]

    return {
        "question": query,
        "query_entities": query_ents,
        "requery_expanded": busca,
        "initial_indices": [int(i) for i in controle_idx],
        "initial_contexts": initial_contexts,
        "reranked": reranked,
        "answer": response,
    }

# %% [markdown]
# ### Testando o sistema de RAG

# %%
test_questions = [
    "O que Sócrates queria dizer com: Mas, cidadãos atenienses, parece -me que também os artífices tinham o mesmo defeito dos poetas?",
    "O que epicuro quer dizer em sua carta para meneceu  sobre a morte, onde aponta à idéia de que a morte para nós não é nada e não significa nada para nós?",
    "O que Sócrates diz no trecho onde explica o que aconteceria se os homens fossem libertados de suas correntes e curados de sua desrazão?"
]

for question in test_questions:
    result = rag_response(
        query=question,
        index=index,
        df_subset=df_subset,
        top_k=10,
        verbose=False
    )

    print("\n=== Avaliação RAG ===")
    print(f"Pergunta: {result['question']}")
    ents = ", ".join(sorted(set(e.get('text','') for e in result.get('query_entities', []) if e.get('text'))))
    print(f"Entidades (query): {ents if ents else '—'}")
    print(f"Query Expandida: {result['requery_expanded']}")

    print("\nContextos iniciais (similaridade):")
    for i, ctx in enumerate(result['initial_contexts'][:5], start=1):
        meta = f"[idx={ctx['idx']}, pag={ctx['pagina_pdf']}, autor={ctx['autor']}, título={ctx['titulo']}]"
        print(f"{i}. {meta} | {ctx['preview'][:200]}...")

    print("\nContextos após reranking (Cross-Encoder + boost):")
    for i, ctx in enumerate(result['reranked'][:5], start=1):
        meta = f"[idx={ctx['idx']}, score={ctx['score']:.4f}, pag={ctx['pagina_pdf']}, autor={ctx['autor']}, título={ctx['titulo']}]"
        print(f"{i}. {meta} | {ctx['preview'][:200]}...")

    print("\nResposta do LLM:")
    print(result['answer'])
    print("====================\n")
# Out:
# === Avaliação RAG ===
# Pergunta: O que Sócrates queria dizer com: Mas, cidadãos atenienses, parece -me que também os artífices tinham o mesmo defeito dos poetas?
# Entidades (query): Sócrates
# Query Expandida: O que Sócrates queria dizer com: Mas, cidadãos atenienses, parece -me que também os artífices tinham o mesmo defeito dos poetas? Sócrates
#
# Contextos iniciais (similaridade):
# 1. [idx=18, pag=6, autor=Platão, título=Apologia de Sócrates] | TITULO: Apologia de Sócrates AUTOR: Platão PAGINA: 6 NER:  TEXTO: VI
# Depois prossegui se mais me deter. embora vendo, amargurado e
# temeroso, que estava incorrendo em ódio; mas também me parecia
# dev...
# 2. [idx=10, pag=4, autor=Platão, título=Apologia de Sócrates] | TITULO: Apologia de Sócrates AUTOR: Platão PAGINA: 4 NER: Paros Cálias de Hipônico Cálias TEXTO: persuadir a e star com eles, deixando as outras conversações,
# compensado-os com dinheiro e proporciona...
# 3. [idx=20, pag=6, autor=Platão, título=Apologia de Sócrates] | TITULO: Apologia de Sócrates AUTOR: Platão PAGINA: 6 NER:  TEXTO: inclinação, e intuição, assim como os adivinhos e os vates; e em
# verdade, embora digam muitas e belas coisas, não sabem nada daquilo ...
# 4. [idx=22, pag=7, autor=Platão, título=Apologia de Sócrates] | TITULO: Apologia de Sócrates AUTOR: Platão PAGINA: 7 NER:  TEXTO: artífices tinham o mesmo defeito dos poetas: pelo fato de exercitar
# bem a própria arte, cada um pretendia ser sapientíssimo também na...
# 5. [idx=19, pag=6, autor=Platão, título=Apologia de Sócrates] | TITULO: Apologia de Sócrates AUTOR: Platão PAGINA: 6 NER:  TEXTO: políticos, fui aos poetas trágicos, e, dos ditirâmbicos fui aos outros,
# convencido de que, entre esses, eu seria de fato apanhado com...
#
# Contextos após reranking (Cross-Encoder + boost):
# 1. [idx=22, score=3.8781, pag=7, autor=Platão, título=Apologia de Sócrates] | TITULO: Apologia de Sócrates AUTOR: Platão PAGINA: 7 NER:  TEXTO: artífices tinham o mesmo defeito dos poetas: pelo fato de exercitar
# bem a própria arte, cada um pretendia ser sapientíssimo também na...
# 2. [idx=19, score=1.3258, pag=6, autor=Platão, título=Apologia de Sócrates] | TITULO: Apologia de Sócrates AUTOR: Platão PAGINA: 6 NER:  TEXTO: políticos, fui aos poetas trágicos, e, dos ditirâmbicos fui aos outros,
# convencido de que, entre esses, eu seria de fato apanhado com...
# 3. [idx=20, score=0.5100, pag=6, autor=Platão, título=Apologia de Sócrates] | TITULO: Apologia de Sócrates AUTOR: Platão PAGINA: 6 NER:  TEXTO: inclinação, e intuição, assim como os adivinhos e os vates; e em
# verdade, embora digam muitas e belas coisas, não sabem nada daquilo ...
# 4. [idx=18, score=-1.6866, pag=6, autor=Platão, título=Apologia de Sócrates] | verdade, me aconteceu o seguinte: procurando segundo o dedo do
# deus, pareceu -me que os mais estimados eram quase privados do
# melhor, e que, ao contrário, os outros, reputados ineptos, eram homens
# ...
# 5. [idx=31, score=-2.5195, pag=9, autor=Platão, título=Apologia de Sócrates] | TITULO: Apologia de Sócrates AUTOR: Platão PAGINA: 9 NER: Oh! TEXTO: - Oh! Que grande desgraça descobriste em mim! E responde -me: será
# assim também para os cavalos? que aqueles que os tonam melhores...
#
# Resposta do LLM:
# Com base no contexto fornecido, Sócrates está destacando um padrão de comportamento que observou em diferentes grupos profissionais durante sua investigação sobre o significado do oráculo de Delfos. Quando ele afirma que "os artífices tinham o mesmo defeito dos poetas", está se referindo à tendência de especialistas em determinadas áreas de presumirem ter sabedoria também em assuntos mais amplos e fundamentais, que vão além de sua expertise específica.
#
# Segundo Sócrates, tanto os poetas quanto os artífices (artesãos ou profissionais especializados) cometiam o mesmo erro: por dominarem bem sua arte particular, acreditavam ser "sapientíssimos também nas outras coisas de maior importância". Esse excesso de confiança baseado em uma competência específica acabava por "obscurecer o seu saber", ou seja, sua habilidade técnica tornava-se um véu que impedia que reconhecessem sua própria ignorância em questões mais essenciais da vida e do conhecimento.
#
# Isso se conecta diretamente com a missão filosófica de Sócrates: enquanto esses profissionais confundiam competência técnica
# ====================
#
#
# === Avaliação RAG ===
# Pergunta: O que epicuro quer dizer em sua carta para meneceu  sobre a morte, onde aponta à idéia de que a morte para nós não é nada e não significa nada para nós?
# Entidades (query): epicuro
# Query Expandida: O que epicuro quer dizer em sua carta para meneceu  sobre a morte, onde aponta à idéia de que a morte para nós não é nada e não significa nada para nós? epicuro
#
# Contextos iniciais (similaridade):
# 1. [idx=103, pag=1, autor=Epicuro, título=Carta a Meneceu] | TITULO: Carta a Meneceu AUTOR: Epicuro PAGINA: 1 NER: A Morte Acostuma-te TEXTO: diferente deles.
#
# 3 - A Morte
#
# Acostuma-te à idéia de que a morte para nós não é nada, visto que todo o bem e
# todo...
# 2. [idx=128, pag=4, autor=Platão, título=O Mito da Caverna] | TITULO: O Mito da Caverna AUTOR: Platão PAGINA: 4 NER: Glauco Sócrates Glauco enganarás TEXTO: tentasse retirar os seus laços, fazê-los subir, você acredita que, se
# pudessem agarrá-lo e executá-lo, n...
# 3. [idx=104, pag=2, autor=Epicuro, título=Carta a Meneceu] | TITULO: Carta a Meneceu AUTOR: Epicuro PAGINA: 2 NER:  TEXTO: 2
# que não há nada de terrível em deixar de viver. É tolo portanto quem diz ter medo da
# morte, não porque a chegada desta lhe trará sofri...
# 4. [idx=93, pag=27, autor=Platão, título=Apologia de Sócrates] | TITULO: Apologia de Sócrates AUTOR: Platão PAGINA: 27 NER:  TEXTO: Porque morrer é uma ou outra destas duas coisas: ou o morto não tem
# absolutamente nenhuma existência, nenhuma consciência do que que...
# 5. [idx=101, pag=1, autor=Epicuro, título=Carta a Meneceu] | TITULO: Carta a Meneceu AUTOR: Epicuro PAGINA: 1 NER: Pratica Os Deuses TEXTO: foram, e para o jovem poder envelhecer sem sentir medo das coisas que estão por vir; é
# necessário, portanto, cuidar das ...
#
# Contextos após reranking (Cross-Encoder + boost):
# 1. [idx=103, score=9.6427, pag=1, autor=Epicuro, título=Carta a Meneceu] | TITULO: Carta a Meneceu AUTOR: Epicuro PAGINA: 1 NER: A Morte Acostuma-te TEXTO: diferente deles.
#
# 3 - A Morte
#
# Acostuma-te à idéia de que a morte para nós não é nada, visto que todo o bem e
# todo...
# 2. [idx=106, score=2.6348, pag=2, autor=Epicuro, título=Carta a Meneceu] | TITULO: Carta a Meneceu AUTOR: Epicuro PAGINA: 2 NER: Hades Desejos e a Tranqüilidade de Espírito
#
# Consideremos TEXTO: transpor o mais depressa possível as portas do Hades.
# Se ele diz isso com plen...
# 3. [idx=101, score=1.5552, pag=1, autor=Epicuro, título=Carta a Meneceu] | TITULO: Carta a Meneceu AUTOR: Epicuro PAGINA: 1 NER: Pratica Os Deuses TEXTO: foram, e para o jovem poder envelhecer sem sentir medo das coisas que estão por vir; é
# necessário, portanto, cuidar das ...
# 4. [idx=104, score=1.0327, pag=2, autor=Epicuro, título=Carta a Meneceu] | está sendo esperado.
# Então, o mais terrível de todos os males, a morte, não significa nada para nós,
# justamente porque, quando estamos vivos, é a morte que não está presente; ao contrário,
# quando a...
# 5. [idx=93, score=-1.4566, pag=27, autor=Platão, título=Apologia de Sócrates] | TITULO: Apologia de Sócrates AUTOR: Platão PAGINA: 27 NER:  TEXTO: Porque morrer é uma ou outra destas duas coisas: ou o morto não tem
# absolutamente nenhuma existência, nenhuma consciência do que que...
#
# Resposta do LLM:
# Com base no texto da Carta a Meneceu, Epicuro desenvolve um argumento racional para eliminar o medo da morte, fundamentado em sua compreensão da natureza humana e da experiência sensorial. Sua tese central é que **a morte não deve ser temida porque não representa nenhum mal para quem a experimenta**. Isso se baseia em dois pilares principais:
#
# 1. **A morte é a privação das sensações**: Para Epicuro, o bem e o mal residem exclusivamente na sensação (prazer e dor). Como a morte é a cessação definitiva da capacidade de sentir, ela não pode ser experimentada como algo doloroso ou prejudicial. Portanto, **enquanto existimos, a morte não está presente; quando a morte chega, nós deixamos de existir**. Não há, assim, qualquer encontro entre a consciência vivente e a morte que possa gerar sofrimento.
#
# 2. **A aceitação da morte liberta para a vida**: Compreender que a morte "não significa nada" permite desfrutar a vida de forma mais plena e serena. Quem deixa de temer a morte não busca acrescent
# ====================
#
#
# === Avaliação RAG ===
# Pergunta: O que epicuro quer dizer em sua carta para meneceu  sobre a morte, onde aponta à idéia de que a morte para nós não é nada e não significa nada para nós?
# Entidades (query): epicuro
# Query Expandida: O que epicuro quer dizer em sua carta para meneceu  sobre a morte, onde aponta à idéia de que a morte para nós não é nada e não significa nada para nós? epicuro
#
# Contextos iniciais (similaridade):
# 1. [idx=103, pag=1, autor=Epicuro, título=Carta a Meneceu] | TITULO: Carta a Meneceu AUTOR: Epicuro PAGINA: 1 NER: A Morte Acostuma-te TEXTO: diferente deles.
#
# 3 - A Morte
#
# Acostuma-te à idéia de que a morte para nós não é nada, visto que todo o bem e
# todo...
# 2. [idx=128, pag=4, autor=Platão, título=O Mito da Caverna] | TITULO: O Mito da Caverna AUTOR: Platão PAGINA: 4 NER: Glauco Sócrates Glauco enganarás TEXTO: tentasse retirar os seus laços, fazê-los subir, você acredita que, se
# pudessem agarrá-lo e executá-lo, n...
# 3. [idx=104, pag=2, autor=Epicuro, título=Carta a Meneceu] | TITULO: Carta a Meneceu AUTOR: Epicuro PAGINA: 2 NER:  TEXTO: 2
# que não há nada de terrível em deixar de viver. É tolo portanto quem diz ter medo da
# morte, não porque a chegada desta lhe trará sofri...
# 4. [idx=93, pag=27, autor=Platão, título=Apologia de Sócrates] | TITULO: Apologia de Sócrates AUTOR: Platão PAGINA: 27 NER:  TEXTO: Porque morrer é uma ou outra destas duas coisas: ou o morto não tem
# absolutamente nenhuma existência, nenhuma consciência do que que...
# 5. [idx=101, pag=1, autor=Epicuro, título=Carta a Meneceu] | TITULO: Carta a Meneceu AUTOR: Epicuro PAGINA: 1 NER: Pratica Os Deuses TEXTO: foram, e para o jovem poder envelhecer sem sentir medo das coisas que estão por vir; é
# necessário, portanto, cuidar das ...
#
# Contextos após reranking (Cross-Encoder + boost):
# 1. [idx=103, score=9.6427, pag=1, autor=Epicuro, título=Carta a Meneceu] | TITULO: Carta a Meneceu AUTOR: Epicuro PAGINA: 1 NER: A Morte Acostuma-te TEXTO: diferente deles.
#
# 3 - A Morte
#
# Acostuma-te à idéia de que a morte para nós não é nada, visto que todo o bem e
# todo...
# 2. [idx=106, score=2.6348, pag=2, autor=Epicuro, título=Carta a Meneceu] | TITULO: Carta a Meneceu AUTOR: Epicuro PAGINA: 2 NER: Hades Desejos e a Tranqüilidade de Espírito
#
# Consideremos TEXTO: transpor o mais depressa possível as portas do Hades.
# Se ele diz isso com plen...
# 3. [idx=101, score=1.5552, pag=1, autor=Epicuro, título=Carta a Meneceu] | TITULO: Carta a Meneceu AUTOR: Epicuro PAGINA: 1 NER: Pratica Os Deuses TEXTO: foram, e para o jovem poder envelhecer sem sentir medo das coisas que estão por vir; é
# necessário, portanto, cuidar das ...
# 4. [idx=104, score=1.0327, pag=2, autor=Epicuro, título=Carta a Meneceu] | está sendo esperado.
# Então, o mais terrível de todos os males, a morte, não significa nada para nós,
# justamente porque, quando estamos vivos, é a morte que não está presente; ao contrário,
# quando a...
# 5. [idx=93, score=-1.4566, pag=27, autor=Platão, título=Apologia de Sócrates] | TITULO: Apologia de Sócrates AUTOR: Platão PAGINA: 27 NER:  TEXTO: Porque morrer é uma ou outra destas duas coisas: ou o morto não tem
# absolutamente nenhuma existência, nenhuma consciência do que que...
#
# Resposta do LLM:
# Com base no texto da Carta a Meneceu, Epicuro desenvolve um argumento racional para eliminar o medo da morte, fundamentado em sua compreensão da natureza humana e da experiência sensorial. Sua tese central é que **a morte não deve ser temida porque não representa nenhum mal para quem a experimenta**. Isso se baseia em dois pilares principais:
#
# 1. **A morte é a privação das sensações**: Para Epicuro, o bem e o mal residem exclusivamente na sensação (prazer e dor). Como a morte é a cessação definitiva da capacidade de sentir, ela não pode ser experimentada como algo doloroso ou prejudicial. Portanto, **enquanto existimos, a morte não está presente; quando a morte chega, nós deixamos de existir**. Não há, assim, qualquer encontro entre a consciência vivente e a morte que possa gerar sofrimento.
#
# 2. **A aceitação da morte liberta para a vida**: Compreender que a morte "não significa nada" permite desfrutar a vida de forma mais plena e serena. Quem deixa de temer a morte não busca acrescent
# ====================
#
#
# === Avaliação RAG ===
# Pergunta: O que Sócrates diz no trecho onde explica o que aconteceria se os homens fossem libertados de suas correntes e curados de sua desrazão?
# Entidades (query): Sócrates
# Query Expandida: O que Sócrates diz no trecho onde explica o que aconteceria se os homens fossem libertados de suas correntes e curados de sua desrazão? Sócrates
#
# Contextos iniciais (similaridade):
# 1. [idx=120, pag=2, autor=Platão, título=O Mito da Caverna] | TITULO: O Mito da Caverna AUTOR: Platão PAGINA: 2 NER: Glauco Sócrates Glauco Zeus Sócrates Glauco Sócrates TEXTO: Glauco: Evidentemente.
# Sócrates: E se, além disso, houvesse um eco vindo da parede di...
# 2. [idx=127, pag=4, autor=Platão, título=O Mito da Caverna] | TITULO: O Mito da Caverna AUTOR: Platão PAGINA: 4 NER: Sócrates Glauco Sócrates TEXTO: viver como se vive lá.
# Sócrates: Reflita ainda nisto: suponha que esse homem volte à
# caverna e retome o seu anti...
# 3. [idx=121, pag=2, autor=Platão, título=O Mito da Caverna] | TITULO: O Mito da Caverna AUTOR: Platão PAGINA: 2 NER: Glauco Sócrates TEXTO: para o lado da luz, todos esses movimentos o fariam sofrer; ele ficaria
# ofuscado e não poderia distinguir os objetos, dos...
# 4. [idx=122, pag=2, autor=Platão, título=O Mito da Caverna] | TITULO: O Mito da Caverna AUTOR: Platão PAGINA: 2 NER: Sócrates Glauco TEXTO: Sócrates: E se o forçassem a olhar para a própria luz, não achas que
# os olhos lhe doeriam, que ele viraria as costas e vo...
# 5. [idx=123, pag=3, autor=Platão, título=O Mito da Caverna] | TITULO: O Mito da Caverna AUTOR: Platão PAGINA: 3 NER: Sócrates Glauco Sócrates TEXTO: Sócrates: E se o tirarem de lá à força, se o fizessem subir o íngreme
# caminho montanhoso, se não o largassem até...
#
# Contextos após reranking (Cross-Encoder + boost):
# 1. [idx=120, score=4.9559, pag=2, autor=Platão, título=O Mito da Caverna] | sua frente?
# Glauco: Sim, por Zeus.
# Sócrates: Assim sendo, os homens que estão nessas condições não
# poderiam considerar nada como verdadeiro, a não ser as sombras dos
# objetos fabricados.
# Glauco: Não ...
# 2. [idx=93, score=-2.1529, pag=27, autor=Platão, título=Apologia de Sócrates] | ...
# 3. [idx=123, score=-3.0230, pag=3, autor=Platão, título=O Mito da Caverna] | TITULO: O Mito da Caverna AUTOR: Platão PAGINA: 3 NER: Sócrates Glauco Sócrates TEXTO: Sócrates: E se o tirarem de lá à força, se o fizessem subir o íngreme
# caminho montanhoso, se não o largassem até...
# 4. [idx=122, score=-4.1858, pag=2, autor=Platão, título=O Mito da Caverna] | TITULO: O Mito da Caverna AUTOR: Platão PAGINA: 2 NER: Sócrates Glauco TEXTO: Sócrates: E se o forçassem a olhar para a própria luz, não achas que
# os olhos lhe doeriam, que ele viraria as costas e vo...
# 5. [idx=126, score=-4.5039, pag=4, autor=Platão, título=O Mito da Caverna] | que as honras e a confiança assim adquiridas entre os companheiros
# lhe dariam inveja? Ele não pensaria antes, como o herói de Homero,
# que mais vale “viver como escravo de um lavrador” e suportar
# qu...
#
# Resposta do LLM:
# No trecho em questão, Sócrates descreve um processo doloroso e difícil de libertação dos prisioneiros da caverna. Ele explica que, ao serem libertados de suas correntes e curados da "desrazão", os homens passariam por um período de sofrimento e desorientação. Seriam forçados a levantar-se, virar a cabeça, andar e olhar para a luz, o que lhes causaria dor e irritação. Ao chegarem à luz exterior, ficariam ofuscados pelo brilho e inicialmente incapazes de ver os objetos reais que antes só conheciam através de sombras.
#
# Sócrates detalha ainda que o processo de adaptação à nova realidade seria gradual: se o prisioneiro fosse forçado a olhar diretamente para a luz, seus olhos doeriam e ele preferiria voltar para as sombras que considerava mais nítidas e familiares. Apenas com tempo e persistência ele se acostumaria com o mundo real, entendendo que este é mais verdadeiro do que as sombras da caverna.
#
# A referência específica encontra-se no trecho
# ====================
#
#
# === Avaliação RAG ===
# Pergunta: O que Sócrates diz no trecho onde explica o que aconteceria se os homens fossem libertados de suas correntes e curados de sua desrazão?
# Entidades (query): Sócrates
# Query Expandida: O que Sócrates diz no trecho onde explica o que aconteceria se os homens fossem libertados de suas correntes e curados de sua desrazão? Sócrates
#
# Contextos iniciais (similaridade):
# 1. [idx=120, pag=2, autor=Platão, título=O Mito da Caverna] | TITULO: O Mito da Caverna AUTOR: Platão PAGINA: 2 NER: Glauco Sócrates Glauco Zeus Sócrates Glauco Sócrates TEXTO: Glauco: Evidentemente.
# Sócrates: E se, além disso, houvesse um eco vindo da parede di...
# 2. [idx=127, pag=4, autor=Platão, título=O Mito da Caverna] | TITULO: O Mito da Caverna AUTOR: Platão PAGINA: 4 NER: Sócrates Glauco Sócrates TEXTO: viver como se vive lá.
# Sócrates: Reflita ainda nisto: suponha que esse homem volte à
# caverna e retome o seu anti...
# 3. [idx=121, pag=2, autor=Platão, título=O Mito da Caverna] | TITULO: O Mito da Caverna AUTOR: Platão PAGINA: 2 NER: Glauco Sócrates TEXTO: para o lado da luz, todos esses movimentos o fariam sofrer; ele ficaria
# ofuscado e não poderia distinguir os objetos, dos...
# 4. [idx=122, pag=2, autor=Platão, título=O Mito da Caverna] | TITULO: O Mito da Caverna AUTOR: Platão PAGINA: 2 NER: Sócrates Glauco TEXTO: Sócrates: E se o forçassem a olhar para a própria luz, não achas que
# os olhos lhe doeriam, que ele viraria as costas e vo...
# 5. [idx=123, pag=3, autor=Platão, título=O Mito da Caverna] | TITULO: O Mito da Caverna AUTOR: Platão PAGINA: 3 NER: Sócrates Glauco Sócrates TEXTO: Sócrates: E se o tirarem de lá à força, se o fizessem subir o íngreme
# caminho montanhoso, se não o largassem até...
#
# Contextos após reranking (Cross-Encoder + boost):
# 1. [idx=120, score=4.9559, pag=2, autor=Platão, título=O Mito da Caverna] | sua frente?
# Glauco: Sim, por Zeus.
# Sócrates: Assim sendo, os homens que estão nessas condições não
# poderiam considerar nada como verdadeiro, a não ser as sombras dos
# objetos fabricados.
# Glauco: Não ...
# 2. [idx=93, score=-2.1529, pag=27, autor=Platão, título=Apologia de Sócrates] | ...
# 3. [idx=123, score=-3.0230, pag=3, autor=Platão, título=O Mito da Caverna] | TITULO: O Mito da Caverna AUTOR: Platão PAGINA: 3 NER: Sócrates Glauco Sócrates TEXTO: Sócrates: E se o tirarem de lá à força, se o fizessem subir o íngreme
# caminho montanhoso, se não o largassem até...
# 4. [idx=122, score=-4.1858, pag=2, autor=Platão, título=O Mito da Caverna] | TITULO: O Mito da Caverna AUTOR: Platão PAGINA: 2 NER: Sócrates Glauco TEXTO: Sócrates: E se o forçassem a olhar para a própria luz, não achas que
# os olhos lhe doeriam, que ele viraria as costas e vo...
# 5. [idx=126, score=-4.5039, pag=4, autor=Platão, título=O Mito da Caverna] | que as honras e a confiança assim adquiridas entre os companheiros
# lhe dariam inveja? Ele não pensaria antes, como o herói de Homero,
# que mais vale “viver como escravo de um lavrador” e suportar
# qu...
#
# Resposta do LLM:
# No trecho em questão, Sócrates descreve um processo doloroso e difícil de libertação dos prisioneiros da caverna. Ele explica que, ao serem libertados de suas correntes e curados da "desrazão", os homens passariam por um período de sofrimento e desorientação. Seriam forçados a levantar-se, virar a cabeça, andar e olhar para a luz, o que lhes causaria dor e irritação. Ao chegarem à luz exterior, ficariam ofuscados pelo brilho e inicialmente incapazes de ver os objetos reais que antes só conheciam através de sombras.
#
# Sócrates detalha ainda que o processo de adaptação à nova realidade seria gradual: se o prisioneiro fosse forçado a olhar diretamente para a luz, seus olhos doeriam e ele preferiria voltar para as sombras que considerava mais nítidas e familiares. Apenas com tempo e persistência ele se acostumaria com o mundo real, entendendo que este é mais verdadeiro do que as sombras da caverna.
#
# A referência específica encontra-se no trecho
# ====================
